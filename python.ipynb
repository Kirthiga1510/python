# %% [markdown]
# <a href="https://colab.research.google.com/github/Kirthiga1510/python/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
celsius = float(input("Enter temperature: "))
fahrenheit = (celsius * 9/5) + 32
kelvin = celsius + 273.15
print("Temperature in Fahrenheit:", fahrenheit)
print("Temperature in Kelvin:", kelvin)
# Out:
# Enter temperature: 20
# Temperature in Fahrenheit: 68.0
# Temperature in Kelvin: 293.15

# %%
word = input("Enter a word: ")
if word == word[::-1]:
    print("it is a palindrome.")
else:
    print(" is not a palindrome.")
# Out:
# Enter a word: 121
# it is a palindrome.

# %%
def my_leap(year):
    if (year%4==0):
       print("leap year")
    else:
       print("not a leap year")
my_leap(2025)
# Out:
# not a leap year

# %%
def my_fib(n):
    if n <= 0:
        print("Enter the number")
        return
    first, second = 0, 1
    print("Fibonacci series",n)
    for i in range(n):
        print(first, end=' ')
        next = first + second
        first = second
        second = next
    print()
n = int(input("Enter the number: "))
my_fib(n)
# Out:
# Enter the number: 3
# Fibonacci series 3
# 0 1 1

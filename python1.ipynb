# %% [markdown]
# <a href="https://colab.research.google.com/github/Kirthiga1510/python/blob/main/python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
questions = [
    {
        "question": "What is the capital of France?",
        "options": ["A) Berlin", "B) Madrid", "C) Paris", "D) Rome"],
        "answer": "C"
    },
    {
        "question": "Who developed the Python language?",
        "options": ["A) Dennis Ritchie", "B) Guido van Rossum", "C) James Gosling", "D) Bjarne Stroustrup"],
        "answer": "B"
    },
    {
        "question": "What is the largest planet in our solar system?",
        "options": ["A) Earth", "B) Mars", "C) Jupiter", "D) Saturn"],
        "answer": "C"
    }
]

def ask_question(question_data):
    print(question_data["question"])
    for option in question_data["options"]:
        print(option)

    answer = input("Enter your answer (A/B/C/D): ").upper()
    return answer == question_data["answer"]

def start_quiz():
    score = 0


    for question_data in questions:

        if ask_question(question_data):
            print("Correct!\n")
            score += 1
        else:
            print(f"Wrong! The correct answer was {question_data['answer']}\n")


    total_questions = len(questions)
    final_score = (score / total_questions) * 100
    print(f"Your final score is {final_score}%")


    if final_score >= 80:
        print("Great job! You passed the quiz.")
    elif final_score >= 50:
        print("Good effort! You can improve next time.")
    else:
        print("Better luck next time!")


def main():
    start_quiz()


    restart = input("Would you like to restart the quiz? (yes/no): ").lower()
    if restart == "yes":
        main()

if __name__ == "__main__":
    main()
# Out:
# What is the capital of France?
# A) Berlin
# B) Madrid
# C) Paris
# D) Rome
# Correct!
#
# Who developed the Python language?
# A) Dennis Ritchie
# B) Guido van Rossum
# C) James Gosling
# D) Bjarne Stroustrup
# Correct!
#
# What is the largest planet in our solar system?
# A) Earth
# B) Mars
# C) Jupiter
# D) Saturn
# Correct!
#
# Your final score is 100.0%
# Great job! You passed the quiz.
